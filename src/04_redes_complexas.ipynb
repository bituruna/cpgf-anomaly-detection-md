# %%
class Grafo:

    def __init__(self, nrovertices):
        self.__vertices = nrovertices
        self.__arestas = [[] for i in range (nrovertices)]

    def vertices(self):
        print(self.__vertices)

    def arestas(self):
        print(self.__arestas)

    def insereAresta(self, origem, destino):
        if (origem < 0 or origem >= self.__vertices):
            return False
        if (destino < 0 or destino >= self.__vertices):
            return False
        self.__arestas[origem].append(destino)
        return True

    def imprimeGrafo(self):
        for i in range(self.__vertices):
            print(i, "->", self.__arestas[i])

   #Faça uma função para que uma aresta seja removida da lista do vértice respectivo.
   #Parametros da func, origem e destino, para saber qual a aresta deseja-se remover, precisamo saber o nodo de origem e destino
    def removeArestas(self, origem, destino):
        #Verficar se existe arestas nos vertices: Solução GPT
        if (origem < 0 or origem >= self.__vertices):
            return False
        if (destino < 0 or destino >= self.__vertices):
            return False

      #1p verificar se os vertices origem e destino possuem arestas
        for i in range(self.__vertices):
            #print(i)
            if i == origem:
              for j in (self.__arestas[origem]):
                if destino == j:
                  print(j)
                  self.__arestas[origem].remove(destino)
                  g.imprimeGrafo()
                  return True
                else:
                  print("Valor não existe")
                  return False



    #Faça uma função, que dados dois vértices, verifica se são adjacentes. Retorna True, em caso positivo, e False em caso negativo.
    def verificaAdjacencia(self,origem,destino):
        if destino in self.__arestas[origem]:
            return True
        elif origem in self.__arestas[destino]:
            return True
        else:
          print("Os vértices não são adjascentes. ")
          return False

# %%
#Modo de uso
g = Grafo(5)
g.insereAresta(4,1)
g.insereAresta(4,2)
g.insereAresta(1,3)
g.insereAresta(0,2)
g.insereAresta(2,1)
g.insereAresta(3,4)
g.insereAresta(3,3)
g.insereAresta(3,1)
